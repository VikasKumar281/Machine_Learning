# %% [markdown]
# # FETCHING THA DATA FROM AN API

# %%
import pandas as pd
import requests

# %%
responses = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=7a4a468a0daa4cdc406659d358b24ac7&&language=en-US&page=1')

# %%
# It is a dictionary----------------------------------------->
responses.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 35.8474,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.71,
#    'vote_count': 28330},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
responses.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 35.8474,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.71,
#   'vote_count': 28330},
#  {'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg  [18, 80]  278                en
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg  [18, 80]  238                en
#
#              original_title  \
# 0  The Shawshank Redemption
# 1             The Godfather
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     35.8474
# 1  Spanning the years 1945 to 1955, a chronicle o...     31.6607
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
#
#    video  vote_average  vote_count
# 0  False         8.710       28330
# 1  False         8.686       21462

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     35.8474
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     31.6607
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     17.0763
# 3  The true story of how businessman Oskar Schind...   1993-12-15     19.4687
# 4  The defense and the prosecution have rested an...   1957-04-10     15.9030
#
#    vote_average  vote_count
# 0         8.710       28330
# 1         8.686       21462
# 2         8.570       12966
# 3         8.565       16446
# 4         8.549        9134

# %%
df = pd.DataFrame()

# %%
# Empty Dataframe--------------------->
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    
    # Here We do STRING FORMATTING --------------------------------------------------->
    responses = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=feefc11f5f70042ca334457913bc3834&&language=en-US&page={i}',timeout = 10)
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[140], line 5
#       1 for i in range(1,429):
#       2
#       3     # Here We do STRING FORMATTING --------------------------------------------------->
#       4     responses = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=feefc11f5f70042ca334457913bc3834&&language=en-US&page={i}',timeout = 10)
# ----> 5     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#       6     df = df.append(temp_df,ignore_index=True)
#
# KeyError: 'results'

# %%
# df.to_csv('movies.csv')
